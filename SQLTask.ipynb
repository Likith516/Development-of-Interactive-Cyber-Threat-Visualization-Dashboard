# %% [markdown]
# <a href="https://colab.research.google.com/github/Likith516/Development-of-Interactive-Cyber-Threat-Visualization-Dashboard/blob/main/SQLTask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
file_path = '/cyber_attack_dataset_q4_2025.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# #Task 1: Display DataFrame Information

# %%
print("--- Task 1: DataFrame Information ---")
df.info()
# Out:
# --- Task 1: DataFrame Information ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   attacker_ip        500 non-null    object
#  1   target_ip          500 non-null    object
#  2   attacker_location  500 non-null    object
#  3   attack_type        500 non-null    object
#  4   attack_device      500 non-null    object
#  5   security_type      500 non-null    object
#  6   attack_date        500 non-null    object
#  7   severity           500 non-null    object
# dtypes: object(8)
# memory usage: 31.4+ KB

# %% [markdown]
# #Task 2: Display First 10 Rows

# %%
print("\n--- Task 2: First 10 Rows ---")
display(df.head(10))
# Out:
# --- Task 2: First 10 Rows ---
#        attacker_ip       target_ip attacker_location          attack_type  \
# 0  215.147.246.227   10.239.58.162             China                 DDoS
# 1  212.188.129.154    10.67.28.139               USA                 DDoS
# 2   95.255.232.209   10.11.105.179            Russia          Brute Force
# 3   142.95.106.162    10.164.2.134             China  Credential Stuffing
# 4      188.3.34.96  10.201.196.119             India     Zero-day Exploit
# 5    108.78.48.253  10.105.152.119            Brazil    Man-in-the-Middle
# 6   208.154.201.31    10.23.29.180             China  Credential Stuffing
# 7   74.124.248.202     10.15.23.29           Ukraine    Man-in-the-Middle
# 8     40.1.194.121   10.51.244.158           Ukraine             Phishing
# 9    74.99.181.136    10.40.11.180                UK    Man-in-the-Middle
#
#   attack_device        security_type attack_date  severity
# 0    IoT Sensor        Email Gateway  11/22/2025      High
# 1      Cloud VM                  WAF  12/17/2025    Medium
# 2    Web Server  Endpoint Protection   11/8/2025      High
# 3      Cloud VM              IDS/IPS  10/14/2025      High
# 4    IoT Camera                  WAF  10/25/2025       Low
# 5        Mobile              IDS/IPS  12/15/2025  Critical
# 6    Web Server              IDS/IPS  11/11/2025    Medium
# 7    Web Server              IDS/IPS  11/25/2025       Low
# 8    IoT Sensor              IDS/IPS  12/23/2025  Critical
# 9    IoT Camera              IDS/IPS  11/20/2025      High

# %% [markdown]
# #Task 3: Display Descriptive Statistics

# %%
print("\n--- Task 3: Descriptive Statistics ---")
display(df.describe(include='all'))
# Out:
# --- Task 3: Descriptive Statistics ---
#            attacker_ip     target_ip attacker_location       attack_type  \
# count              500           500               500               500
# unique             500           500                10                 8
# top     39.211.160.117  10.249.11.67             China  Zero-day Exploit
# freq                 1             1                65                71
#
#        attack_device security_type attack_date  severity
# count            500           500         500       500
# unique             6             6          91         4
# top       Web Server       IDS/IPS   12/7/2025  Critical
# freq              93            91          12       128

# %% [markdown]
# #Task 4: Analyze Distribution of attack_type

# %%
print("\n--- Task 4: Distribution of attack_type ---")
attack_type_dist = df['attack_type'].value_counts()
print(attack_type_dist)
# Out:
# --- Task 4: Distribution of attack_type ---
# attack_type
# Zero-day Exploit       71
# SQL Injection          68
# Phishing               67
# Man-in-the-Middle      64
# Brute Force            61
# Credential Stuffing    59
# DDoS                   58
# Ransomware             52
# Name: count, dtype: int64

# %% [markdown]
# #Task 5: Identify Unique Values in Key Categorical Columns

# %%
print("\n--- Task 5: Unique Values ---")
cols_to_check = ['attack_type', 'attack_device', 'security_type', 'severity']
for col in cols_to_check:
    print(f"{col}: {df[col].unique()}")
# Out:
# --- Task 5: Unique Values ---
# attack_type: ['DDoS' 'Brute Force' 'Credential Stuffing' 'Zero-day Exploit'
#  'Man-in-the-Middle' 'Phishing' 'Ransomware' 'SQL Injection']
# attack_device: ['IoT Sensor' 'Cloud VM' 'Web Server' 'IoT Camera' 'Mobile' 'Server']
# security_type: ['Email Gateway' 'WAF' 'Endpoint Protection' 'IDS/IPS' 'Firewall'
#  'Zero Trust']
# severity: ['High' 'Medium' 'Low' 'Critical']

# %% [markdown]
# #Task 6: Analyze Severity Distribution

# %%
print("\n--- Task 6: Severity Distribution ---")
severity_dist = df['severity'].value_counts()
print(severity_dist)
# Out:
# --- Task 6: Severity Distribution ---
# severity
# Critical    128
# High        125
# Low         125
# Medium      122
# Name: count, dtype: int64
